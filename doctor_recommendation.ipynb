# %%
import numpy as np
import pandas as pd

# %%
# main dataset
df = pd.read_csv('dataset.csv')
df
# Out:
#             Disease           Symptom_0           Symptom_1  \
# 0              AIDS      muscle_wasting   patches_in_throat
# 1              AIDS   patches_in_throat          high_fever
# 2              AIDS      muscle_wasting          high_fever
# 3              AIDS      muscle_wasting   patches_in_throat
# 4              AIDS      muscle_wasting   patches_in_throat
# ..              ...                 ...                 ...
# 308  Varicose veins              cramps            bruising
# 309  Varicose veins             fatigue              cramps
# 310  Varicose veins             fatigue              cramps
# 311  Varicose veins             fatigue              cramps
# 312  Varicose veins             fatigue              cramps
#
#                    Symptom_2                Symptom_3               Symptom_4  \
# 0                 high_fever   extra_marital_contacts                     NaN
# 1     extra_marital_contacts                      NaN                     NaN
# 2     extra_marital_contacts                      NaN                     NaN
# 3     extra_marital_contacts                      NaN                     NaN
# 4                 high_fever                      NaN                     NaN
# ..                       ...                      ...                     ...
# 308                  obesity             swollen_legs   swollen_blood_vessels
# 309                 bruising                  obesity            swollen_legs
# 310                 bruising                  obesity            swollen_legs
# 311                 bruising             swollen_legs   swollen_blood_vessels
# 312                 bruising                  obesity            swollen_legs
#
#                     Symptom_5                 Symptom_6 Symptom_7 Symptom_8  \
# 0                         NaN                       NaN       NaN       NaN
# 1                         NaN                       NaN       NaN       NaN
# 2                         NaN                       NaN       NaN       NaN
# 3                         NaN                       NaN       NaN       NaN
# 4                         NaN                       NaN       NaN       NaN
# ..                        ...                       ...       ...       ...
# 308   prominent_veins_on_calf                       NaN       NaN       NaN
# 309     swollen_blood_vessels   prominent_veins_on_calf       NaN       NaN
# 310   prominent_veins_on_calf                       NaN       NaN       NaN
# 311   prominent_veins_on_calf                       NaN       NaN       NaN
# 312     swollen_blood_vessels                       NaN       NaN       NaN
#
#     Symptom_9 Symptom_10 Symptom_11 Symptom_12 Symptom_13 Symptom_14  \
# 0         NaN        NaN        NaN        NaN        NaN        NaN
# 1         NaN        NaN        NaN        NaN        NaN        NaN
# 2         NaN        NaN        NaN        NaN        NaN        NaN
# 3         NaN        NaN        NaN        NaN        NaN        NaN
# 4         NaN        NaN        NaN        NaN        NaN        NaN
# ..        ...        ...        ...        ...        ...        ...
# 308       NaN        NaN        NaN        NaN        NaN        NaN
# 309       NaN        NaN        NaN        NaN        NaN        NaN
# 310       NaN        NaN        NaN        NaN        NaN        NaN
# 311       NaN        NaN        NaN        NaN        NaN        NaN
# 312       NaN        NaN        NaN        NaN        NaN        NaN
#
#     Symptom_15 Symptom_16
# 0          NaN        NaN
# 1          NaN        NaN
# 2          NaN        NaN
# 3          NaN        NaN
# 4          NaN        NaN
# ..         ...        ...
# 308        NaN        NaN
# 309        NaN        NaN
# 310        NaN        NaN
# 311        NaN        NaN
# 312        NaN        NaN
#
# [313 rows x 18 columns]

# %%
# Other important datasets
df_precaution = pd.read_csv('disease_precaution.csv')
df_description = pd.read_csv('disease_description.csv')
df_specialist = pd.read_csv('Doctor_Versus_Disease.csv',encoding='latin1', names=['Disease','Specialist'])

# %%
df_specialist
# Out:
#                                     Disease           Specialist
# 0                             Drug Reaction            Allergist
# 1                                   Allergy            Allergist
# 2                             Hypertension          Cardiologist
# 3                              Heart attack         Cardiologist
# 4                                 Psoriasis        Dermatologist
# 5                               Chicken pox        Dermatologist
# 6                                      Acne        Dermatologist
# 7                                  Impetigo        Dermatologist
# 8                          Fungal infection        Dermatologist
# 9                            Hypothyroidism      Endocrinologist
# 10                                Diabetes       Endocrinologist
# 11                             Hypoglycemia      Endocrinologist
# 12                          Hyperthyroidism      Endocrinologist
# 13                                     GERD   Gastroenterologist
# 14                      Peptic ulcer diseae   Gastroenterologist
# 15                                 Jaundice   Gastroenterologist
# 16             Dimorphic hemmorhoids(piles)  Gastroenterologist
# 17                          Gastroenteritis   Gastroenterologist
# 18                  Urinary tract infection         Gynecologist
# 19                      Chronic cholestasis         Hepatologist
# 20                              hepatitis A         Hepatologist
# 21                              Hepatitis B         hepatologist
# 22                              Hepatitis C         Hepatologist
# 23                              Hepatitis E         Hepatologist
# 24                              Hepatitis D         Hepatologist
# 25                      Alcoholic hepatitis         Hepatologist
# 26                                  Malaria     Internal Medcine
# 27                                   Dengue     Internal Medcine
# 28                                 Migraine          Neurologist
# 29                     Cervical spondylosis          Neurologist
# 30             Paralysis (brain hemorrhage)          Neurologist
# 31                                     AIDS          Osteopathic
# 32  (vertigo) Paroymsal  Positional Vertigo     Otolaryngologist
# 33                              Common Cold     Otolaryngologist
# 34                                  Typhoid         Pediatrician
# 35                           Varicose veins         Phlebologist
# 36                         Bronchial Asthma        Pulmonologist
# 37                                Pneumonia        Pulmonologist
# 38                          Osteoarthristis      Rheumatologists
# 39                                Arthritis      Rheumatologists
# 40                             Tuberculosis         Tuberculosis

# %%
df_precaution.head()
# Out:
#                Disease      Symptom_precaution_0      Symptom_precaution_1  \
# 0                 AIDS           avoid open cuts      wear ppe if possible
# 1                 Acne                bath twice    avoid fatty spicy food
# 2  Alcoholic hepatitis  stop alcohol consumption            consult doctor
# 3              Allergy            apply calamine   cover area with bandage
# 4            Arthritis                  exercise  use hot and cold therapy
#
#     Symptom_precaution_2         Symptom_precaution_3
# 0         consult doctor                    follow up
# 1  drink plenty of water      avoid too many products
# 2             medication                    follow up
# 3                    NaN  use ice to compress itching
# 4        try acupuncture                      massage

# %% [markdown]
# 1. Here we are dropping the disease column and then joining the tuples of all symptoms_precaution as Precaution
# 2. Next we form a new dataset, by dropping the columns of df_try and and concatening it with the disease column
# 3. This forms a new dataset named df_precaution

# %%
df_try = df_precaution.drop(columns ='Disease')
df_try['Precaution'] = df_try.apply(lambda row: " ".join(row.values.astype(str)),axis =1)

# %%
df_try = df_try.drop(['Symptom_precaution_0','Symptom_precaution_1','Symptom_precaution_2','Symptom_precaution_3'],axis =1)

# %%
df_try = pd.concat([df_precaution['Disease'],df_try],axis =1)
df_try.head()
# Out:
#                Disease                                         Precaution
# 0                 AIDS  avoid open cuts wear ppe if possible consult d...
# 1                 Acne  bath twice avoid fatty spicy food drink plenty...
# 2  Alcoholic hepatitis  stop alcohol consumption consult doctor medica...
# 3              Allergy  apply calamine cover area with bandage nan use...
# 4            Arthritis  exercise use hot and cold therapy try acupunct...

# %%
df_precaution = df_try
df_precaution.head()
# Out:
#                Disease                                         Precaution
# 0                 AIDS  avoid open cuts wear ppe if possible consult d...
# 1                 Acne  bath twice avoid fatty spicy food drink plenty...
# 2  Alcoholic hepatitis  stop alcohol consumption consult doctor medica...
# 3              Allergy  apply calamine cover area with bandage nan use...
# 4            Arthritis  exercise use hot and cold therapy try acupunct...

# %% [markdown]
# 1. Here we are dropping the disease column and then joining the tuples of all symptoms making a new column Symptoms
# 2. Next we form a new dataset, by dropping the columns of df_main and and concatening it with the disease column
# 3. This forms a new dataset named df.. making this our main dataset of disease and their symptoms.

# %%
df.fillna('',inplace =True)

# %%
df_main = df.drop(columns='Disease')

# %%
df_main['Symptoms'] = df_main.apply(lambda row: " ".join(row.values.astype(str)),axis =1)

# %%
df_main = df_main.drop(['Symptom_0','Symptom_1','Symptom_2','Symptom_3','Symptom_4','Symptom_5','Symptom_6','Symptom_7','Symptom_8','Symptom_9','Symptom_10','Symptom_11','Symptom_12','Symptom_13','Symptom_14','Symptom_15','Symptom_16',],axis =1)

# %%
df_main['Symptoms'] = df_main['Symptoms'].str.replace('_'," ")

# %%
df_main = pd.concat([df['Disease'],df_main],axis =1)

# %%
df = df_main
df.head()
# Out:
#   Disease                                           Symptoms
# 0    AIDS   muscle wasting  patches in throat  high fever...
# 1    AIDS   patches in throat  high fever  extra marital ...
# 2    AIDS   muscle wasting  high fever  extra marital con...
# 3    AIDS   muscle wasting  patches in throat  extra mari...
# 4    AIDS   muscle wasting  patches in throat  high fever...

# %% [markdown]
# We will use TFIDF Vectorizer to extract features from the text

# %%
# using NLP from here
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vec = TfidfVectorizer(max_features=5000)
x = vec.fit_transform(df['Symptoms']).toarray()
y = df['Disease']

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score,classification_report

# %% [markdown]
# Splitting the Dataset

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3)

# %%
model = MultinomialNB()
model.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
y_pred =model.predict(x_test)
y_pred
# Out:
# array(['Drug Reaction', 'Hepatitis E', 'Peptic ulcer disease', 'Jaundice',
#        'Gastroenteritis', 'Typhoid', 'Varicose veins', 'Bronchial Asthma',
#        'Varicose veins', 'Chronic cholestasis', 'Hepatitis D', 'Dengue',
#        'Impetigo', 'Hypoglycemia', 'Hypertension ', 'GERD', 'Diabetes ',
#        'Chicken pox', 'Paroxysmal Positional Vertigo', 'Malaria',
#        'Malaria', 'Diabetes ', 'Covid', 'Varicose veins', 'Arthritis',
#        'Pneumonia', 'Dimorphic hemorrhoids(piles)', 'Common Cold',
#        'Jaundice', 'Alcoholic hepatitis', 'Malaria', 'Common Cold',
#        'Dengue', 'Migraine', 'Migraine', 'Chronic cholestasis', 'GERD',
#        'Typhoid', 'Malaria', 'Pneumonia', 'Hepatitis D', 'Psoriasis',
#        'Dengue', 'Dimorphic hemorrhoids(piles)', 'Chicken pox',
#        'Hepatitis C', 'Malaria', 'Hepatitis B', 'Urinary tract infection',
#        'Hypoglycemia', 'Urinary tract infection', 'Osteoarthritis',
#        'Chicken pox', 'Covid', 'Jaundice', 'Dengue', 'Psoriasis',
#        'Hepatitis A', 'Osteoarthritis', 'Malaria', 'Varicose veins',
#        'Malaria', 'Tuberculosis', 'Malaria', 'Tuberculosis',
#        'Osteoarthritis', 'Hepatitis E', 'Jaundice', 'Alcoholic hepatitis',
#        'Hepatitis A', 'Hyperthyroidism', 'Hepatitis A', 'Osteoarthritis',
#        'Varicose veins', 'Chronic cholestasis', 'Chronic cholestasis',
#        'Hypoglycemia', 'Tuberculosis', 'Pneumonia', 'Hepatitis E',
#        'Migraine', 'Chronic cholestasis', 'Drug Reaction', 'GERD',
#        'Dimorphic hemorrhoids(piles)', 'Cervical spondylosis',
#        'Hyperthyroidism', 'Hepatitis B', 'Chronic cholestasis',
#        'Chronic cholestasis', 'Chicken pox', 'Pneumonia', 'Diabetes ',
#        'Bronchial Asthma'], dtype='<U29')

# %%
print("Accuracy Score: ",accuracy_score(y_test,y_pred))
print("Classification Report:\n",classification_report(y_test,y_pred))
# Out:
# Accuracy Score:  0.8085106382978723
# Classification Report:
#                                 precision    recall  f1-score   support
#
#                          AIDS       0.00      0.00      0.00         3
#                          Acne       0.00      0.00      0.00         3
#           Alcoholic hepatitis       1.00      1.00      1.00         2
#                     Arthritis       1.00      0.33      0.50         3
#              Bronchial Asthma       1.00      1.00      1.00         2
#          Cervical spondylosis       0.00      0.00      0.00         0
#                   Chicken pox       1.00      1.00      1.00         4
#           Chronic cholestasis       0.00      0.00      0.00         0
#                   Common Cold       1.00      1.00      1.00         2
#                         Covid       1.00      1.00      1.00         2
#                        Dengue       1.00      1.00      1.00         4
#                     Diabetes        1.00      1.00      1.00         3
#  Dimorphic hemorrhoids(piles)       1.00      1.00      1.00         3
#                 Drug Reaction       1.00      1.00      1.00         2
#              Fungal infection       0.00      0.00      0.00         3
#                          GERD       1.00      1.00      1.00         3
#               Gastroenteritis       1.00      0.50      0.67         2
#                   Hepatitis A       1.00      1.00      1.00         3
#                   Hepatitis B       1.00      1.00      1.00         2
#                   Hepatitis C       1.00      0.50      0.67         2
#                   Hepatitis D       1.00      0.67      0.80         3
#                   Hepatitis E       1.00      1.00      1.00         3
#                 Hypertension        1.00      0.50      0.67         2
#               Hyperthyroidism       1.00      1.00      1.00         2
#                  Hypoglycemia       1.00      1.00      1.00         3
#                      Impetigo       1.00      1.00      1.00         1
#                      Jaundice       1.00      1.00      1.00         4
#                       Malaria       0.00      0.00      0.00         0
#                      Migraine       1.00      1.00      1.00         3
#                Osteoarthritis       0.50      1.00      0.67         2
#  Paralysis (brain hemorrhage)       0.00      0.00      0.00         3
# Paroxysmal Positional Vertigo       1.00      1.00      1.00         1
#          Peptic ulcer disease       1.00      1.00      1.00         1
#                     Pneumonia       1.00      1.00      1.00         4
#                     Psoriasis       1.00      1.00      1.00         2
#                  Tuberculosis       1.00      1.00      1.00         3
#                       Typhoid       1.00      1.00      1.00         2
#       Urinary tract infection       1.00      1.00      1.00         2
#                Varicose veins       1.00      1.00      1.00         5
#
#                      accuracy                           0.81        94
#                     macro avg       0.81      0.76      0.77        94
#                  weighted avg       0.86      0.81      0.82        94
# C:\Users\Darshan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Darshan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Darshan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Darshan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Darshan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Darshan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
def pred_prognosis():
    user_symptoms = input("Enter ur symptoms")
    user_symptoms = user_symptoms.lower().replace('[^\w\s]','')
    symps_vec = vec.transform([user_symptoms]).toarray()
    prognosis = model.predict(symps_vec)
    result = pd.DataFrame({'Disease':prognosis}) 
    result = result.merge(df_specialist, on="Disease",how="left")
    result = result.merge(df_precaution, on="Disease", how = "left")
    result = result.merge(df_description, on="Disease",how="left")

    return result

# %%
pred_prognosis()
# Out:
#        Disease        Specialist  \
# 0  Common Cold  Otolaryngologist
#
#                                           Precaution  \
# 0  drink vitamin c rich drinks take vapour avoid ...
#
#                                  Symptom_Description
# 0  The common cold is a viral infection of your n...
